# %%
import datetime

# %%
datetime.MAXYEAR
# Out:
# 9999

# %%
datetime.datetime.today()
# Out:
# datetime.datetime(2025, 12, 23, 17, 35, 33, 382109)

# %%
datetime.date.today()
# Out:
# datetime.date(2025, 12, 23)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 12, 23, 17, 40, 8, 731545)

# %%
datetime.date(2025,4,5)
# Out:
# datetime.date(2025, 4, 5)

# %%
dt=datetime.datetime(2050,8,9,3,1,4)

# %%
dt.year, dt.second
# Out:
# (2050, 4)

# %%
datetime.datetime.now()-datetime.timedelta(0)
# Out:
# datetime.datetime(2025, 12, 23, 17, 50, 37, 802838)
