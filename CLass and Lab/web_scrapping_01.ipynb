# %% [markdown]
# ### making the soup:

# %%
## method 1:

from bs4 import BeautifulSoup
with open('day_26 variable and custom properties.html') as file:
    soup=BeautifulSoup(file,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>variable and custom properties</title>
# </head>
# <style>
#     :root{
#         --box-color: rgb(23, 177, 113) ;
#     }
#     .box{
#         width: 200px;
#         height: 200px;
#         /* background-color: aqua; */
#         border: 2px solid red;
#         margin: 2px 2px;
#         background-color: var(--box-color) ;
#         box-shadow: 3px 3px var(--box-color);
#
#     }
#     .container{
#         max-width: 733px;
#         /* max width vanda badi jhanna */
#         margin: auto;
#         border: 2px solid red;
#         display: flex;
#         justify-content: center;
#         height: 500px;
#         width: 100%;
#         align-items: center;
#     }
# </style>
# <body>
# <div class="container">
# <div class="box">suresh</div>
# <div class="box"></div>
# <div class="box"></div>
# </div>
# </body>
# </html>

# %%
# access particular table
tag=soup.div
type(tag)
# Out:
# bs4.element.Tag

# %%
# for access class
soup.find(class_='container')
# Out:
# <div class="container">
# <div class="box">suresh</div>
# <div class="box"></div>
# <div class="box"></div>
# </div>

# %%
soup.div
# Out:
# <div class="container">
# <div class="box">suresh</div>
# <div class="box"></div>
# <div class="box"></div>
# </div>

# %%
# to chhange tag name 
tag=soup.div
tag.name='fuck'
tag
# Out:
# <fuck class="container">
# <div class="box">suresh</div>
# <div class="box"></div>
# <div class="box"></div>
# </fuck>

# %%
# to access class 
tag=soup.div
tag['class']
# Out:
# ['box']

# %%
# accessing as a text or string form 
tag.string  ,  type(tag.string)
# Out:
# ('suresh', bs4.element.NavigableString)

# %%
# to change into str 
str(tag.string)    , type(str(tag.string))
# Out:
# ('suresh', str)

# %%
tag=soup.find_all('div')
