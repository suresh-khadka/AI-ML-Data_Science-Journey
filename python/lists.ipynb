# %% [markdown]
# ## list is a data structure in python. it is a mutable or changable, order sequence of element.

# %%
a=[]
a.append(90)
print(a)
# Out:
# [90]

# %%
a.count(90)
# Out:
# 1

# %%
min(a)
# Out:
# 90
