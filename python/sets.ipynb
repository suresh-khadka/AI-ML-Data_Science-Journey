# %%
#set
a={1,4,5,3,7,10,2,1,1}
print(a)
# Out:
# {1, 2, 3, 4, 5, 7, 10}

# %%
set1={"suresh","khadka","lion"}
print(set1)
set2={"tilak","khadka","tiger"}
print(set2)
set2.intersection(set1)
# Out:
# {'lion', 'khadka', 'suresh'}
# {'khadka', 'tilak', 'tiger'}
# {'khadka'}

# %%
set1
# Out:
# {'khadka', 'lion', 'suresh'}

# %%
set1.difference(set2)
# Out:
# {'lion', 'suresh'}

# %%
#dictionary
# Out:
# {'khadka'}
