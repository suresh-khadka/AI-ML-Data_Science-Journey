# %% [markdown]
# # this is first tutorial
# ## 1.welcome

# %% [markdown]
# ## ceilis a inbuilt fun that is in math. it provide heighest number of that given number
# ## floor provide samll of that given

# %%
import math
a=40.05
a=math.ceil(a)
print(a)
# Out:
# 41

# %%
math.floor(a)
# Out:
# 41

# %% [markdown]
# # exp

# %%
math.exp(10)
# Out:
# 22026.465794806718

# %%
#log
math.log(40)
# Out:
# 3.6888794541139363

# %%
math.log2(2)
# Out:
# 1.0

# %%
#max(),min()
print(max(21,90,5,6,89,100))
print(min(21,90,5,6,89,100))
# Out:
# 100
# 5

# %%
#pow
pow(2,4)
# Out:
# 16

# %%
math.pow(4,1/2) #this is just like sqrt() function
# Out:
# 2.0

# %%
a=math.radians(90) #convert 90 degree value in radians
math.sin(a)
# Out:
# 1.0

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.modf(12.34)
# Out:
# (0.33999999999999986, 12.0)
