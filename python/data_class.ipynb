# %%
from dataclasses import dataclass

@dataclass
class person:
    name:str
    age:int
    profession:str

# %%
p=person("suresh",20,'data scienists')
print(p.age)
print(p.profession)
# Out:
# 20
# data scienists
