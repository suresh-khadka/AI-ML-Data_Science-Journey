# %%
empty_dict={}
print(empty_dict)
type(empty_dict)
# Out:
# {}
# dict

# %%
my_dict={"name":"suresh","last_name":"khadka","age":20}
print(my_dict)
# Out:
# {'name': 'suresh', 'last_name': 'khadka', 'age': 20}

# %%
#indexing
my_dict["name"]
# Out:
# 'suresh'

# %%
for i in my_dict:
    print(i)
# Out:
# name
# last_name
# age

# %%
for i in my_dict.values():
    print(i)
# Out:
# suresh
# khadka
# 20

# %%
for i in my_dict.items():
    print(i)
# Out:
# ('name', 'suresh')
# ('last_name', 'khadka')
# ('age', 20)

# %%
#add new item to dict
my_dict["sex"]="male"
my_dict
# Out:
# {'name': 'suresh', 'last_name': 'khadka', 'age': 20, 'sex': 'male'}

# %%
#nested dictionary
man1={"name":"suresh","age":20}
man2={"name":"tilak","age":18}
man3={"name":"dipu","age":15}
person_dict={"per1":man1,"per2":man2,"per3":man3}
person_dict
# Out:
# {'per1': {'name': 'suresh', 'age': 20},
#  'per2': {'name': 'tilak', 'age': 18},
#  'per3': {'name': 'dipu', 'age': 15}}

# %%
#INDEXING
person_dict['per2']['name']
# Out:
# 'tilak'
