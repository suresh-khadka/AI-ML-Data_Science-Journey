# %% [markdown]
# ## k-means clustering

# %%
import pandas as pd

# %%
df=pd.read_csv('student_clustering.csv')
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
df.isnull().sum()
# Out:
# cgpa    0
# iq      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
# for clustering
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),wcss)

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=i)
km.fit_predict(X)
# Out:
# array([0, 1, 2, 6, 1, 4, 6, 3, 1, 2, 5, 1, 6, 0, 4, 9, 1, 8, 1, 1, 6, 5,
#        8, 0, 0, 6, 0, 7, 2, 4, 3, 1, 7, 4, 9, 9, 7, 4, 5, 1, 5, 9, 2, 5,
#        3, 3, 2, 4, 7, 4, 5, 5, 3, 9, 3, 4, 1, 3, 4, 3, 4, 9, 9, 7, 0, 1,
#        2, 5, 1, 9, 4, 3, 2, 5, 4, 7, 1, 3, 0, 8, 8, 7, 1, 5, 3, 0, 3, 4,
#        3, 4, 3, 3, 8, 5, 9, 2, 7, 9, 0, 7, 1, 5, 0, 7, 0, 5, 8, 0, 7, 7,
#        2, 3, 4, 1, 8, 7, 9, 4, 3, 0, 0, 4, 2, 7, 6, 5, 6, 4, 0, 9, 2, 1,
#        5, 5, 1, 7, 4, 0, 6, 9, 2, 5, 1, 0, 0, 7, 0, 3, 4, 0, 3, 5, 3, 3,
#        5, 9, 1, 7, 1, 2, 5, 7, 4, 8, 3, 5, 4, 5, 0, 7, 7, 1, 3, 0, 0, 6,
#        3, 4, 0, 3, 3, 4, 1, 4, 9, 0, 2, 8, 3, 1, 2, 2, 0, 5, 9, 0, 7, 1,
#        4, 3], dtype=int32)

# %%
y_means=km.fit_predict(X)

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='blue')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='red')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')
