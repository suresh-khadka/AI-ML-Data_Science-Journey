# %%
import numpy as np
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
import statistics
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()    #describe all
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
np.mean(df['total_bill'])          #to find mean
# Out:
# np.float64(19.78594262295082)

# %%
np.median(df['total_bill'])    #to fins median
# Out:
# np.float64(17.795)

# %%
statistics.mode(df['total_bill'])          # to find mode
# Out:
# 13.42

# %%
np.percentile(df['total_bill'],25)      #to find Q1 or 25 percentile
# Out:
# np.float64(13.3475)

# %%
np.percentile(df['total_bill'],50)    #to find median or q2 or 50 percentile
# Out:
# np.float64(17.795)

# %%
np.percentile(df['total_bill'],75)    #to find  75 percentile or q3
# Out:
# np.float64(24.127499999999998)

# %%
np.max(df['total_bill'])       #to find maxima
# Out:
# 50.81

# %%
plt.figure(figsize=(5, 3))
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df["total_bill"])       #histogram
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'],kde=True)      #histogram along with pde
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=sns.load_dataset("iris")
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df1['sepal_width'],kde=True)   #normal distribution
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.countplot(df1['species'],color='red')
# Out:
# <Axes: xlabel='count', ylabel='species'>
