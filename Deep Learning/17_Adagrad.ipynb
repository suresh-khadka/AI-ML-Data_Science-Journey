# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
import os

os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["PYTHONHASHSEED"] = "0"

# 2. Set non-TensorFlow seeds
import random
import numpy as np

random.seed(42)
np.random.seed(42)

# 3. Import TensorFlow and set its seed last
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten,BatchNormalization

tf.random.set_seed(42)
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### DataSet

# %%
X, y = make_moons(100, noise=0.25,random_state=2)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %% [markdown]
# ###  Without Momentum

# %%
model = Sequential([
    Dense(units=128, activation='relu', input_dim=2), 
    Dense(units=1, activation="sigmoid")
])
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',  metrics=['accuracy'])

history1 = model.fit(X, y, epochs=50, validation_split = 0.2,verbose=1)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.6125 - loss: 0.6565 - val_accuracy: 0.8500 - val_loss: 0.6471
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7375 - loss: 0.6281 - val_accuracy: 0.8500 - val_loss: 0.6212
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.6098 - val_accuracy: 0.8500 - val_loss: 0.6003
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.5950 - val_accuracy: 0.8500 - val_loss: 0.5819
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7500 - loss: 0.5821 - val_accuracy: 0.8500 - val_loss: 0.5653
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7625 - loss: 0.5705 - val_accuracy: 0.8500 - val_loss: 0.5498
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7625 - loss: 0.5598 - val_accuracy: 0.9000 - val_loss: 0.5352
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7875 - loss: 0.5499 - val_accuracy: 0.9000 - val_loss: 0.5214
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7875 - loss: 0.5406 - val_accuracy: 0.9000 - val_loss: 0.5082
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8125 - loss: 0.5317 - val_accuracy: 0.9000 - val_loss: 0.4956
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8125 - loss: 0.5233 - val_accuracy: 0.9000 - val_loss: 0.4834
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8125 - loss: 0.5154 - val_accuracy: 0.9000 - val_loss: 0.4717
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8125 - loss: 0.5078 - val_accuracy: 0.9000 - val_loss: 0.4604
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8125 - loss: 0.5006 - val_accuracy: 0.9000 - val_loss: 0.4495
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8125 - loss: 0.4937 - val_accuracy: 0.9000 - val_loss: 0.4390
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8125 - loss: 0.4872 - val_accuracy: 0.9000 - val_loss: 0.4287
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8125 - loss: 0.4810 - val_accuracy: 0.9000 - val_loss: 0.4189
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8125 - loss: 0.4751 - val_accuracy: 0.9000 - val_loss: 0.4094
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8125 - loss: 0.4695 - val_accuracy: 0.9000 - val_loss: 0.4002
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8250 - loss: 0.4640 - val_accuracy: 0.9000 - val_loss: 0.3912
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8250 - loss: 0.4588 - val_accuracy: 0.9000 - val_loss: 0.3826
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8375 - loss: 0.4539 - val_accuracy: 0.9000 - val_loss: 0.3744
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.4492 - val_accuracy: 0.9000 - val_loss: 0.3664
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8500 - loss: 0.4447 - val_accuracy: 0.9000 - val_loss: 0.3587
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.4404 - val_accuracy: 0.9000 - val_loss: 0.3514
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8375 - loss: 0.4364 - val_accuracy: 0.9000 - val_loss: 0.3445
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8375 - loss: 0.4325 - val_accuracy: 0.9000 - val_loss: 0.3379
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8375 - loss: 0.4289 - val_accuracy: 0.9000 - val_loss: 0.3316
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8500 - loss: 0.4255 - val_accuracy: 0.9000 - val_loss: 0.3257
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8500 - loss: 0.4223 - val_accuracy: 0.9000 - val_loss: 0.3200
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8500 - loss: 0.4193 - val_accuracy: 0.9000 - val_loss: 0.3145
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.4163 - val_accuracy: 0.9000 - val_loss: 0.3093
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8500 - loss: 0.4136 - val_accuracy: 0.9000 - val_loss: 0.3043
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.4110 - val_accuracy: 0.9000 - val_loss: 0.2997
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.4085 - val_accuracy: 0.9000 - val_loss: 0.2953
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.4062 - val_accuracy: 0.9000 - val_loss: 0.2911
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.4039 - val_accuracy: 0.9000 - val_loss: 0.2871
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.4018 - val_accuracy: 0.9000 - val_loss: 0.2833
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.3998 - val_accuracy: 0.9000 - val_loss: 0.2796
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8500 - loss: 0.3979 - val_accuracy: 0.9000 - val_loss: 0.2762
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3961 - val_accuracy: 0.9000 - val_loss: 0.2730
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.3944 - val_accuracy: 0.9000 - val_loss: 0.2700
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8375 - loss: 0.3929 - val_accuracy: 0.9000 - val_loss: 0.2672
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8375 - loss: 0.3914 - val_accuracy: 0.9000 - val_loss: 0.2646
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8375 - loss: 0.3900 - val_accuracy: 0.9000 - val_loss: 0.2621
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8375 - loss: 0.3887 - val_accuracy: 0.9000 - val_loss: 0.2598
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8375 - loss: 0.3874 - val_accuracy: 0.9000 - val_loss: 0.2577
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8375 - loss: 0.3863 - val_accuracy: 0.9000 - val_loss: 0.2557
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8375 - loss: 0.3852 - val_accuracy: 0.9000 - val_loss: 0.2538
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8375 - loss: 0.3841 - val_accuracy: 0.9000 - val_loss: 0.2520

# %%
class KerasClassifierWrapper:
    def __init__(self, model):
        self.model = model
    def predict(self, X):
        preds = self.model.predict(X, verbose=0)
        return (preds > 0.5).astype(int).ravel()  # flatten to 1D int labels

wrapped_model = KerasClassifierWrapper(model)
plot_decision_regions(X, y.astype(int), clf=wrapped_model, legend=2)
plt.xlim(-2, 3)
plt.ylim(-1.5, 2)
plt.show()

# %% [markdown]
# ### Using Adagrad

# %%
model2 = Sequential([
    Dense(units=128, activation='relu', input_dim=2), 
    Dense(units=1, activation="sigmoid")
])

# %%
optimizer=keras.optimizers.Adagrad(
    learning_rate=0.1
)
model2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history2 = model2.fit(X, y, epochs=50, validation_split = 0.2,verbose=1)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.5750 - loss: 0.6902 - val_accuracy: 0.8500 - val_loss: 0.6280
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7125 - loss: 0.6123 - val_accuracy: 0.8500 - val_loss: 0.5526
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5607 - val_accuracy: 0.9000 - val_loss: 0.4935
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7875 - loss: 0.5224 - val_accuracy: 0.9000 - val_loss: 0.4453
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8000 - loss: 0.4931 - val_accuracy: 0.9000 - val_loss: 0.4062
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8125 - loss: 0.4707 - val_accuracy: 0.9000 - val_loss: 0.3751
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8250 - loss: 0.4535 - val_accuracy: 0.9000 - val_loss: 0.3498
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8250 - loss: 0.4402 - val_accuracy: 0.9000 - val_loss: 0.3296
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8250 - loss: 0.4298 - val_accuracy: 0.9000 - val_loss: 0.3134
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8250 - loss: 0.4215 - val_accuracy: 0.9000 - val_loss: 0.3006
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8250 - loss: 0.4149 - val_accuracy: 0.9000 - val_loss: 0.2903
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8375 - loss: 0.4096 - val_accuracy: 0.9000 - val_loss: 0.2820
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8375 - loss: 0.4052 - val_accuracy: 0.9000 - val_loss: 0.2750
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8375 - loss: 0.4016 - val_accuracy: 0.9000 - val_loss: 0.2694
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8375 - loss: 0.3986 - val_accuracy: 0.9000 - val_loss: 0.2646
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8375 - loss: 0.3960 - val_accuracy: 0.9000 - val_loss: 0.2610
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8375 - loss: 0.3939 - val_accuracy: 0.9000 - val_loss: 0.2576
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8375 - loss: 0.3920 - val_accuracy: 0.9000 - val_loss: 0.2550
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8375 - loss: 0.3904 - val_accuracy: 0.9000 - val_loss: 0.2528
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8375 - loss: 0.3889 - val_accuracy: 0.9000 - val_loss: 0.2509
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8375 - loss: 0.3875 - val_accuracy: 0.9000 - val_loss: 0.2493
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8375 - loss: 0.3863 - val_accuracy: 0.9000 - val_loss: 0.2480
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8375 - loss: 0.3852 - val_accuracy: 0.9000 - val_loss: 0.2471
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8375 - loss: 0.3842 - val_accuracy: 0.9000 - val_loss: 0.2462
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8375 - loss: 0.3833 - val_accuracy: 0.9000 - val_loss: 0.2455
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8375 - loss: 0.3824 - val_accuracy: 0.9000 - val_loss: 0.2448
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8375 - loss: 0.3815 - val_accuracy: 0.9000 - val_loss: 0.2442
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8375 - loss: 0.3807 - val_accuracy: 0.9000 - val_loss: 0.2436
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8375 - loss: 0.3799 - val_accuracy: 0.9000 - val_loss: 0.2432
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8375 - loss: 0.3792 - val_accuracy: 0.9000 - val_loss: 0.2427
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3785 - val_accuracy: 0.9000 - val_loss: 0.2423
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3778 - val_accuracy: 0.9000 - val_loss: 0.2422
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8500 - loss: 0.3772 - val_accuracy: 0.9000 - val_loss: 0.2417
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8500 - loss: 0.3766 - val_accuracy: 0.9000 - val_loss: 0.2412
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.3761 - val_accuracy: 0.9000 - val_loss: 0.2408
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.3756 - val_accuracy: 0.9000 - val_loss: 0.2404
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3751 - val_accuracy: 0.9000 - val_loss: 0.2401
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3746 - val_accuracy: 0.9000 - val_loss: 0.2396
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8500 - loss: 0.3742 - val_accuracy: 0.9000 - val_loss: 0.2393
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8500 - loss: 0.3737 - val_accuracy: 0.9000 - val_loss: 0.2389
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8500 - loss: 0.3732 - val_accuracy: 0.9000 - val_loss: 0.2386
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8500 - loss: 0.3728 - val_accuracy: 0.9000 - val_loss: 0.2384
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.3724 - val_accuracy: 0.9000 - val_loss: 0.2382
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8500 - loss: 0.3719 - val_accuracy: 0.9000 - val_loss: 0.2379
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8500 - loss: 0.3715 - val_accuracy: 0.9000 - val_loss: 0.2377
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8500 - loss: 0.3711 - val_accuracy: 0.9000 - val_loss: 0.2373
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8500 - loss: 0.3707 - val_accuracy: 0.9000 - val_loss: 0.2372
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8500 - loss: 0.3703 - val_accuracy: 0.9000 - val_loss: 0.2369
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8500 - loss: 0.3698 - val_accuracy: 0.9000 - val_loss: 0.2368
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8500 - loss: 0.3694 - val_accuracy: 0.9000 - val_loss: 0.2365

# %%
class KerasClassifierWrapper:
    def __init__(self, model):
        self.model = model
    def predict(self, X):
        preds = self.model.predict(X, verbose=0)
        return (preds > 0.5).astype(int).ravel()  # flatten to 1D int labels

wrapped_model = KerasClassifierWrapper(model2)
plot_decision_regions(X, y.astype(int), clf=wrapped_model, legend=2)
plt.xlim(-2, 3)
plt.ylim(-1.5, 2)
plt.show()

# %%
plt.plot(history1.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])

plt.legend(['Without Momentum', 'With Adagrad'])

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history1.history['val_loss'], label='Without Momentum')
plt.plot(history2.history['val_loss'], label='With Adagrad')

plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Validation Loss Comparison")
plt.legend()

plt.show()

# %% [markdown]
# ### Conclusion :
# ##### Fast Convergence
